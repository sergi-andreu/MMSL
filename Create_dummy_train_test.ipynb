# %%
import pandas as pd
import numpy as np

from data import Data

# %%
train_df = pd.read_csv("project_train.csv")
train_df.loc[84, "energy"] = 0.734
train_df.loc[94, "loudness"] = -6.542
train_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.545   0.884    5    -4.807     0       0.3670      0.290000
# 1           0.795   0.545    7    -8.153     1       0.3430      0.003960
# 2           0.489   0.871    5    -5.825     1       0.3860      0.002850
# 3           0.539   0.931    4    -1.803     0       0.2620      0.000713
# 4           0.918   0.734   11    -2.832     0       0.2690      0.029400
# ..            ...     ...  ...       ...   ...          ...           ...
# 500         0.897   0.612   11   -10.489     1       0.2110      0.029700
# 501         0.728   0.454    0    -9.281     1       0.0278      0.512000
# 502         0.571   0.837    0    -5.604     1       0.0377      0.165000
# 503         0.582   0.720   10    -9.722     0       0.2310      0.012700
# 504         0.697   0.474    9    -6.663     1       0.0351      0.603000
#
#      instrumentalness  liveness  valence    tempo  Label
# ...

# %%
train_df = train_df.sample(frac=1).reset_index(drop=True)
train_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.662  0.2440    8   -15.322     1       0.0399        0.8720
# 1           0.590  0.7240    0    -3.278     1       0.0439        0.0400
# 2           0.301  0.0823    1   -23.282     1       0.0382        0.9920
# 3           0.730  0.6380    6    -5.320     0       0.0336        0.0999
# 4           0.573  0.9050   11    -4.833     1       0.1080        0.1090
# ..            ...     ...  ...       ...   ...          ...           ...
# 500         0.757  0.7250    0    -4.860     0       0.0315        0.1850
# 501         0.789  0.8580    1    -5.542     1       0.3110        0.1270
# 502         0.532  0.7830    2    -5.697     1       0.0523        0.0038
# 503         0.551  0.5610    2    -6.940     1       0.0835        0.3700
# 504         0.811  0.5660    8    -6.033     0       0.5170        0.5630
#
#      instrumentalness  liveness  valence    tempo  Label
# ...

# %%
new_test_df = train_df.loc[0:100]
new_test_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.662  0.2440    8   -15.322     1       0.0399        0.8720
# 1           0.590  0.7240    0    -3.278     1       0.0439        0.0400
# 2           0.301  0.0823    1   -23.282     1       0.0382        0.9920
# 3           0.730  0.6380    6    -5.320     0       0.0336        0.0999
# 4           0.573  0.9050   11    -4.833     1       0.1080        0.1090
# ..            ...     ...  ...       ...   ...          ...           ...
# 96          0.426  0.9570    0    -8.028     0       0.1920        0.0159
# 97          0.490  0.0803    7   -13.220     1       0.0522        0.9450
# 98          0.528  0.2820    4   -16.449     0       0.0309        0.9470
# 99          0.189  0.3490   11   -16.035     1       0.0435        0.8890
# 100         0.246  0.1090    3   -23.065     1       0.0429        0.9890
#
#      instrumentalness  liveness  valence    tempo  Label
# ...

# %%
new_train_df = train_df.loc[100:]
new_train_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 100         0.246   0.109    3   -23.065     1       0.0429        0.9890
# 101         0.512   0.887    0    -4.245     1       0.3450        0.0166
# 102         0.389   0.047    5   -20.711     0       0.0512        0.9950
# 103         0.422   0.396    9    -9.048     1       0.0306        0.5790
# 104         0.610   0.175    6   -18.089     1       0.0340        0.7680
# ..            ...     ...  ...       ...   ...          ...           ...
# 500         0.757   0.725    0    -4.860     0       0.0315        0.1850
# 501         0.789   0.858    1    -5.542     1       0.3110        0.1270
# 502         0.532   0.783    2    -5.697     1       0.0523        0.0038
# 503         0.551   0.561    2    -6.940     1       0.0835        0.3700
# 504         0.811   0.566    8    -6.033     0       0.5170        0.5630
#
#      instrumentalness  liveness  valence    tempo  Label
# ...

# %%
new_train_df.to_csv("dummy_train.csv", index=False)
new_test_df.to_csv("dummy_test.csv", index=False)
